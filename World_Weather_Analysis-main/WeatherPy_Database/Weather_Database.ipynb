# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# ## Retrieving the Nearest City

# %%
#Create set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Make list 'coordinates' from zipped lat_lngs file
coordinates = list(lat_lngs)

# Get nearest city from list lat_lngs using citipy
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 772

# %% [markdown]
# ## Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies requests and API for OpenWeatherMap
import requests
from config import weather_api_key

# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yar-sale
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | zeya
# Processing Record 5 of Set 1 | zwedru
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | saint-pierre
# Processing Record 8 of Set 1 | narsaq
# Processing Record 9 of Set 1 | svetlogorsk
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | geraldton
# Processing Record 12 of Set 1 | kahului
# Processing Record 13 of Set 1 | port hedland
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | saldanha
# Processing Record 18 of Set 1 | baghmara
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | kirov
# ...

# %%
# Check lenght of city_data
len(city_data)
# Out:
# 704

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yar-Sale      RU  66.8333   70.8333    -12.32       100          89
# 1  Punta Arenas      CL -53.1500  -70.9167     51.91        32           0
# 2    Butaritari      KI   3.0707  172.7902     82.60        72          57
# 3          Zeya      RU  53.7500  127.2667     -6.29        88          12
# 4        Zwedru      LR   6.0667   -8.1281     80.82        56          35
# 5      Hermanus      ZA -34.4187   19.2345     66.90        84          98
# 6  Saint-Pierre      RE -21.3393   55.4781     78.48        69           0
# 7        Narsaq      GL  60.9167  -46.0500     17.82        78           4
# 8   Svetlogorsk      BY  52.6333   29.7333     37.42        94         100
# 9       Mataura      NZ -46.1927  168.8643     57.47        67          89
#
#    Wind Speed Current Description
# 0        5.03     overcast clouds
# 1       23.02           clear sky
# 2       18.32       broken clouds
# ...

# %%
# Output created dataframe to CSV
output_data_file = "WeatherPy_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
